# %%
import pandas as pd




# dfp1 = pd.read_excel('./naiv_1.xlsx')
# dfp2 = pd.read_excel('./naiv_2.xlsx')
# dfp3 = pd.read_excel('./naiv_3.xlsx')
# dfp4 = pd.read_excel('./naiv_4 .xlsx')



# dfp1 = pd.read_excel('./know_1.xlsx')
# dfp2 = pd.read_excel('./know_2.xlsx')
# dfp3 = pd.read_excel('./know_3.xlsx')
# dfp4 = pd.read_excel('./know_4.xlsx')


dfp1 = pd.read_excel('./soph_1.xlsx')
dfp2 = pd.read_excel('./soph_2.xlsx')
dfp3 = pd.read_excel('./soph_3.xlsx')
dfp4 = pd.read_excel('./soph_4.xlsx')

# %%
dfp1
# Out:
#    Index   Acc_tda   Pre_tda   Rec_tda  Acc_ifum  Pre_ifum  Rec_ifum  \
# 0      1  0.999273  0.899819  0.566797  0.892630  0.001461  0.190570
# 1      2  0.999359  0.890866  0.656884  0.891453  0.004707  0.185613
# 2      3  0.998073  0.869436  0.597532  0.890961  0.005397  0.178146
# 3      4  0.998021  0.847886  0.622706  0.890383  0.007011  0.178640
#
#     Acc_lof   Pre_lof   Rec_lof  Acc_ocsvm  Pre_ocsvm  Rec_ocsvm
# 0  0.894235  0.003982  0.370169   0.894297   0.003014   0.350569
# 1  0.894072  0.006783  0.367246   0.893984   0.007255   0.367976
# 2  0.893642  0.010546  0.363323   0.893694   0.009264   0.357479
# 3  0.893483  0.010979  0.359097   0.893297   0.012762   0.361285

# %%
dfp2
# Out:
#    Index   Acc_tda   Pre_tda   Rec_tda  Acc_ifum  Pre_ifum  Rec_ifum  \
# 0      5  0.997259  0.869118  0.605736  0.889574  0.008969  0.181403
# 1      6  0.997283  0.880485  0.648392  0.889595  0.008898  0.184921
# 2      7  0.996826  0.877548  0.625636  0.888716  0.011556  0.188023
# 3      8  0.996560  0.872183  0.642004  0.887974  0.012851  0.183230
# 4      9  0.995376  0.856868  0.605372  0.887220  0.014250  0.178363
#
#     Acc_lof   Pre_lof   Rec_lof  Acc_ocsvm  Pre_ocsvm  Rec_ocsvm
# 0  0.892964  0.018709  0.375172   0.892500   0.019249   0.358627
# 1  0.892802  0.021215  0.380694   0.892736   0.020048   0.380046
# 2  0.892654  0.021191  0.373844   0.892613   0.021481   0.373087
# 3  0.891764  0.028219  0.369368   0.892089   0.025927   0.368476
# 4  0.891455  0.034409  0.381778   0.891513   0.034043   0.383016

# %%
df_con = pd.concat([dfp1,dfp2,dfp3,dfp4])
# df_con = pd.concat([dfp1,dfp2,dfp3])
# df_con = dfp1

# %%
# df_con = dfp1

# %%
# combined_cells = (df + df2 +df3) / 3
combined_cells = (df_con ) / 1
print("Average for each cell across dataframes:")
print(combined_cells)
# Out:
# Average for each cell across dataframes:
#    Index   Acc_tda   Pre_tda   Rec_tda  Acc_ifum  Pre_ifum  Rec_ifum  \
# 0    1.0  0.999273  0.899819  0.566797  0.892630  0.001461  0.190570
# 1    2.0  0.999359  0.890866  0.656884  0.891453  0.004707  0.185613
# 2    3.0  0.998073  0.869436  0.597532  0.890961  0.005397  0.178146
# 3    4.0  0.998021  0.847886  0.622706  0.890383  0.007011  0.178640
# 0    5.0  0.997259  0.869118  0.605736  0.889574  0.008969  0.181403
# 1    6.0  0.997283  0.880485  0.648392  0.889595  0.008898  0.184921
# 2    7.0  0.996826  0.877548  0.625636  0.888716  0.011556  0.188023
# 3    8.0  0.996560  0.872183  0.642004  0.887974  0.012851  0.183230
# 4    9.0  0.995376  0.856868  0.605372  0.887220  0.014250  0.178363
# 0   10.0  0.995352  0.851850  0.621977  0.886460  0.016468  0.182777
# 1   11.0  0.995125  0.861246  0.629960  0.886101  0.018416  0.189113
# 2   12.0  0.994222  0.867328  0.619132  0.885296  0.018892  0.180399
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(20, 5))

# Subplot 1: Naive
plt.subplot(1, 3, 1)
plt.plot(combined_cells['Index']*5, (combined_cells['Acc_tda'])*100, marker='o', label='Our approach (TDA)')
plt.plot(combined_cells['Index']*5, (combined_cells['Acc_ifum'])*100, marker='x', label='IFUM')
plt.plot(combined_cells['Index']*5, (combined_cells['Acc_lof'])*100, marker='s', label='LOFM')
plt.plot(combined_cells['Index']*5, (combined_cells['Acc_ocsvm'])*100, marker='^', label='OCSVM')

plt.xlabel('Percentage of tampering Super-providers', fontsize=14,fontweight='bold')
plt.ylabel('Accuracy (%)', fontsize=14,fontweight='bold')
plt.title('(A) Accuracy', fontsize=16,fontweight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.xlim([0, 100])  
plt.ylim([0, 100]) 

# Subplot 2: Know1
plt.subplot(1, 3, 2)
plt.plot(combined_cells['Index']*5, (combined_cells['Pre_tda'])*100, marker='o', label='Our approach (TDA)')
plt.plot(combined_cells['Index']*5, (combined_cells['Pre_ifum'])*100, marker='x', label='IFUM')
plt.plot(combined_cells['Index']*5, (combined_cells['Pre_lof'])*100, marker='s', label='LOFM')
plt.plot(combined_cells['Index']*5, (combined_cells['Pre_ocsvm'])*100, marker='^', label='OCSVM')

plt.xlabel('Percentage of tampering Super-providers', fontsize=14,fontweight='bold')
plt.ylabel('Precision (%)', fontsize=14,fontweight='bold')
plt.title('(B) Precision', fontsize=16,fontweight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.xlim([0, 100])  
plt.ylim([0, 100]) 

# Subplot 3: Sps
plt.subplot(1, 3, 3)
plt.plot(combined_cells['Index']*5, (combined_cells['Rec_tda'])*100, marker='o', label='Our approach (TDA)')
plt.plot(combined_cells['Index']*5, (combined_cells['Rec_ifum'])*100, marker='x', label='IFUM')
plt.plot(combined_cells['Index']*5, (combined_cells['Rec_lof'])*100, marker='s', label='LOFM')
plt.plot(combined_cells['Index']*5, (combined_cells['Rec_ocsvm'])*100, marker='s', label='OCSVM')

plt.xlabel('Percentage of tampering Super-providers', fontsize=14,fontweight='bold')
plt.ylabel('Recall (%)', fontsize=14,fontweight='bold')
plt.title('(C) Recall', fontsize=16,fontweight='bold')
plt.legend(fontsize=12)
plt.grid(True)
plt.xlim([0, 100])  
plt.ylim([0, 100]) 

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(combined_cells['Index']*5, (combined_cells['AM'])*100, marker='o', label='Our approch')
# plt.plot(combined_cells['Index']*5, (combined_cells['AB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Accuracy (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(combined_cells['Index']*10, (combined_cells['PM'])*100, marker='o', label='Our approch')
# plt.plot(combined_cells['Index']*10, (combined_cells['PB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Precision (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(combined_cells['Index']*10, (combined_cells['RM'])*100, marker='o', label='Our approch')
# plt.plot(combined_cells['Index']*10, (combined_cells['RB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Recall (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))

# Subplot 1: Naive
plt.subplot(2, 2, 1)
plt.plot(combined_cells['Index']*10, (combined_cells['AM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*10, (combined_cells['AB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Accuracy (%)')
plt.title('(A) Accuracy')
plt.legend()
plt.grid(True)
plt.grid(True)

# Subplot 2: Know1
plt.subplot(2, 2, 2)
plt.plot(combined_cells['Index']*10, (combined_cells['PM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*10, (combined_cells['PB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Precision (%)')
plt.title('(B) Precision')
plt.legend()
plt.grid(True)
plt.grid(True)

# Subplot 3: Sps
plt.subplot(2, 2, 3)
plt.plot(combined_cells['Index']*10, (combined_cells['RM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*10, (combined_cells['RB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Recall (%)')
plt.title('(C) Recall')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(df_time['NumberSP'], (df_time['Time']), marker='o', label='Our approch')

plt.xlabel('Number of Microcells')
plt.ylabel('Time taken for the algorithem (S)')
plt.title('(D) Scalability')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(20, 5))

# Subplot 1: Naive
plt.subplot(1, 3, 1)
plt.plot(combined_cells['Index']*5, (combined_cells['AM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*5, (combined_cells['AB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Accuracy (%)')
plt.title('(A) Accuracy')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.xlim([0, 100])  
plt.ylim([0, 100]) 

# Subplot 2: Know1
plt.subplot(1, 3, 2)
plt.plot(combined_cells['Index']*5, (combined_cells['PM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*5, (combined_cells['PB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Precision (%)')
plt.title('(B) Precision')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.xlim([0, 100])  
plt.ylim([0, 100]) 

# Subplot 3: Sps
plt.subplot(1, 3, 3)
plt.plot(combined_cells['Index']*5, (combined_cells['RM'])*100, marker='o', label='Our approch')
plt.plot(combined_cells['Index']*5, (combined_cells['RB'])*100, marker='x', label='Baseline')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Recall (%)')
plt.title('(C) Recall')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.xlim([0, 100])  
plt.ylim([0, 100]) 


plt.tight_layout()
plt.show()

# %%
df3

# %%
df4

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))

# Subplot 1: Naive
plt.subplot(3, 1, 1)
plt.plot(df1['Index']*10, (df1['A']+df2['A'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['A']+df4['A'])*50, marker='x', label='Knowledgeable')
plt.xlabel('Number of tampering Super-providers')
plt.ylabel('Accuracy')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)

# Subplot 2: Know1
plt.subplot(3, 1, 2)
plt.plot(df1['Index']*10, (df1['B']+df2['B'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['B']+df4['B'])*50, marker='x', label='Knowledgeable')
plt.xlabel('Number of tampering Super-providers')
plt.ylabel('Precision')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)

# Subplot 3: Sps
plt.subplot(3, 1, 3)
plt.plot(df1['Index']*10, (df1['C']+df2['C'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['C']+df4['C'])*50, marker='x', label='Knowledgeable')
plt.xlabel('Number of tampering Super-providers')
plt.ylabel('Recall')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(df1['Index']*10, (df1['A']+df2['A'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['A']+df4['A'])*50, marker='x', label='Knowledgeable')

plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Accuracy (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(df1['Index']*10, (df1['B']+df2['B'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['B']+df4['B'])*50, marker='x', label='Knowledgeable')
plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Precision (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(12, 8))


plt.plot(df1['Index']*10, (df1['C']+df2['C'])*50, marker='o', label='Naive')
plt.plot(df3['Index']*10, (df3['C']+df4['C'])*50, marker='x', label='Knowledgeable')
plt.xlabel('Percentage of tampering Super-providers')
plt.ylabel('Recall (%)')
plt.title('Line Graph')
plt.legend()
plt.grid(True)
plt.grid(True)

plt.show()
