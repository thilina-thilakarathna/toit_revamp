# %%
from experiments.experiment1 import Experiment1


experiment1 = Experiment1()

# %%
experiment1.setup()
# Out:
# {'M102':       serviceid providerid microcell   timestamp  speed  latency  bandwidth  \
# 0        100002   P1000002      M102  2023-02-19   4.00     4.29       4.18
# 1        100427   P1000033      M102  2024-02-23   4.54     4.58       4.52
# 2        100568   P1000076      M102  2024-01-04   4.25     4.00       4.25
# 3        100579   P1000076      M102  2024-02-25   4.58     4.33       4.58
# 4        100591   P1000002      M102  2024-02-24   4.40     4.29       4.36
# ...         ...        ...       ...         ...    ...      ...        ...
# 2658     162624   P1000074      M110  2023-05-24   4.50     4.50       4.50
# 2659     162661   P1000074      M110  2023-04-01   4.50     4.00       4.50
# 2660     162671   P1000074      M103  2023-04-09   5.00     4.50       5.00
# 2661     162894   P1000074      M103  2023-03-27   5.00     4.00       4.00
# 2662     163727   P1000074      M110  2023-03-20   5.00     5.00       5.00
#
# ...

# %%
experiment1.run()
experiment1.report()
# Out:
# Experiment1 (TDA) running...
# Tampering type: N
# Tampering type: K
# Tampering type: S
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90
# Experiment 1 (TDA) completed. Effectiveness results are available in the output DataFrame.
