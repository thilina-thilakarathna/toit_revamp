# %%
from evaluations.evaluations import Evaluations


evaluations = Evaluations()
evaluations.setup_experments()
# Out:
# Loaded existing evaluation data from CSV.
# Experment setup is complete.

# %%
evaluations.experiment_1()
# Out:
# Running experiment 1 with tampering type: N and tampering percentage: 10
# true_label
# C    70666
# T     1457
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 20
# true_label
# C    57326
# T    14797
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 30
# true_label
# C    63415
# T     8708
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 40
# true_label
# C    59138
# T    12985
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 50
# true_label
# C    58337
# T    13786
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 60
# true_label
# C    57150
# T    14973
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 70
# true_label
# C    54438
# T    17685
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 80
# true_label
# C    40766
# T    31357
# Name: count, dtype: int64
# Running experiment 1 with tampering type: N and tampering percentage: 90
# true_label
# C    37852
# T    34271
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 10
# true_label
# C    67000
# T     5123
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 20
# true_label
# C    38743
# T    33380
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 30
# true_label
# C    51808
# T    20315
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 40
# true_label
# C    52022
# T    20101
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 50
# true_label
# C    39953
# T    32170
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 60
# true_label
# T    50051
# C    22072
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 70
# true_label
# T    44397
# C    27726
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 80
# true_label
# T    55322
# C    16801
# Name: count, dtype: int64
# Running experiment 1 with tampering type: K and tampering percentage: 90
# true_label
# T    64112
# C     8011
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 10
# true_label
# C    72084
# T       39
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 20
# true_label
# C    72019
# T      104
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 30
# true_label
# C    72005
# T      118
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 40
# true_label
# C    71966
# T      157
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 50
# true_label
# C    71918
# T      205
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 60
# true_label
# C    71857
# T      266
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 70
# true_label
# C    71832
# T      291
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 80
# true_label
# C    71778
# T      345
# Name: count, dtype: int64
# Running experiment 1 with tampering type: S and tampering percentage: 90
# true_label
# C    71738
# T      385
# Name: count, dtype: int64
